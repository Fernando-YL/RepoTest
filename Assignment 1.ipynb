# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fernando L** <br>
# Currently a student. I want to be an engineer.

# %% [markdown]
# *I am interested in data science because I want to improve my ability to draw meaningfull conclusions from a large set of data.*

# %% [markdown]
# ### In the next cell, I will sum two numbers ###

# %%
10+10
# Out:
# 20

# %% [markdown]
# |Name|Age|Sex|
# |---|---|---|
# |Leo|20|M|
# |Sarah|19|F|

# %% [markdown]
# - They are friends
# - They like ice cream
# - They live in Toronto

# %% [markdown]
# [link for a wikipedia page] https://pt.wikipedia.org/wiki/Imagem
